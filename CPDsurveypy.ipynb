# %% [markdown]
# <b>Data Wrangling </b><br>
# CPD Survey data 2022

# %% [markdown]
# 1. Install and import pandas

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# 2. Import data set <br>
# (I cleaned the dataset in excel)

# %%
df = pd.read_csv('C:/Users/10205705/OneDrive - State of Ohio/Projects/Projects/Python/CPDsurvey/cpdsurveydata.csv')

# %%
df
# Out:
#     Respondent ID  Collector ID              Start Date  \
# 0             NaN           NaN                     NaN
# 1    1.352814e+10   416083768.0  08/03/2022 02:14:58 PM
# 2    1.352803e+10   416083768.0  08/03/2022 11:55:04 AM
# 3    1.352810e+10   416083768.0  08/03/2022 01:25:36 PM
# 4    1.352811e+10   416083768.0  08/03/2022 01:40:00 PM
# 5    1.351830e+10   416083768.0  07/19/2022 12:19:26 PM
# 6    1.351389e+10   416083768.0  07/12/2022 02:13:17 PM
# 7    1.347847e+10   416083768.0  05/23/2022 09:52:39 AM
# 8    1.347505e+10   416083768.0  05/18/2022 03:24:59 PM
# 9    1.345284e+10   416083768.0  04/22/2022 03:38:00 PM
# 10   1.345028e+10   416083768.0  04/20/2022 09:39:46 AM
# 11   1.344828e+10   416083768.0  04/18/2022 02:23:31 PM
# 12   1.344812e+10   416083768.0  04/18/2022 11:51:30 AM
# 13   1.344168e+10   416083768.0  04/11/2022 03:10:25 PM
# 14   1.343887e+10   416083768.0  04/08/2022 12:27:44 PM
# 15   1.343895e+10   416083768.0  04/08/2022 01:28:44 PM
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Columns: 131 entries, Respondent ID to Unnamed: 130
# dtypes: float64(6), object(125)
# memory usage: 25.7+ KB
